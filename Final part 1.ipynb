# %% [markdown]
# # Quantifying the Abundance of Different Microbes in Your Metagenome using OneCodex:
#
# #### INPUT to terminal:
#
# onecodex login
#
# #### OUTPUT from terminal:
#
# Uploading: 160523Alm_D16-4705_2_sequence.fastq.gz finished.
#
# Uploading: All complete.
#
# #### To upload two files from bioe131 onto onecodex, we used the following input into terminal:
#
# screen
#
# onecodex upload 160523Alm_D16-4705_1_sequence.fastq.gz 160523Alm_D16-4705_2_sequence.fastq.gz
#
# **Description:** this code uploaded two sequences onto onecodex and allowed the samples to be indexed, searched, and compared. Running it in a screen allowed the program to keep running even if the machine went offline.
#
# - After the sequences were uploaded onto onecodex, we went to the onecodex website to look at our results.
#
# #### Results for 160523Alm_D16-4705_1_sequence.fastq.gz are as follows
#
# | Species | Amount in Soil | Description|
# |---------|----------|------------|
# |Cutibacterium acnes|9.84%| linked to skin acne|
# |Actinomyces odontolyticus|4.66%| bacteria causing highly infectious disease|
# |Cladosporium sphaerospermum|4.33%| found in decaying leaves and branches of citrus|
# |Armatimonadetes bacterium 13_1_40CM_64_14|3.64%| found in aquatic plants|
# |Pseudomonas aeruginosa|2.75%| found in many different environments such as soil, water, and plant and animal tissue|
# |Streptomyces californicus|2.58%|originates in moist surfaces|
# |Micrococcus luteus|2.35%| found in soil, dust, water and air, and as part of the normal flora of the mammalian skin|
# |Escherichia coli|2.02%| commonly found in the lower intestine of warm-blooded organisms|
#
# #### *The following species were also found in the sample but at less than 2% concentration.
# | Species | Amount in soil|
# |-------|-------|
# |Nocardioides sp. REDSEA-S25_B9|1.83%|
# |Moraxella osloensis|1.79%|
#
# #### Results for 160523Alm_D16-4705_2_sequence.fastq.gz are as follows:
#
# | Species | Amount in soil| Description|
# |-----------|--------------|------------|
# |Cutibacterium acnes | 9.91% | linked to skin acne|
# |Cladosporium sphaerospermum | 4.33% |found in decaying leaves and branches of citrus|
# |Armatimonadetes bacterium |3.65%|found in aquatic plants|
# |Pseudomonas aeruginosa | 2.60% | found in soil, water, and plant and animal tissue|
# |Escherichia coli | 2.06%| commonly found in the lower intestine of warm-blooded organisms|
#
# #### *The following species were also found in the sample but at a less than 2% concentration.
#
# | Species | Amount in soil|
# |-----------|----------|
# |Williamsia sp. D3 |1.83%|
# |Moraxella osloensis|1.80%|
# |Williamsia muralis|1.59%|
# |Micrococcus luteus|1.52%|
# |Micrococcaceae bacterium JKS001869|1.44%|
# |Acidobacteria bacterium 13_1_20CM_2_60_10|1.43%|
# |Sphingomonas ginsenosidimutans|1.41%|
# |Asanoa ferruginea|1.36%|
# |Methylobacterium sp. CG08_land_8_20_14_0_20_71_15|1.11%|
# |Enhydrobacter sp. H5|1.09%|

# %% [markdown]
# # Assemble your Metagenomeinto Contigs Using the Metaspadespart of SPAdes.
#
# **INPUT to terminal:**
#
#     spades.py --meta -t 10 -m 64 -1 /data/metagenomes/160523Alm_D16-4705_1_sequence.fastq.gz  -2 /data/metagenomes/160523Alm_D16-4705_2_sequence.fastq.gz -o /home/be131-19/FinalProject metaspades_assembly
#
# **OUTPUT from terminal:**
#
# **Description:** The purpose of this code is to use the sequences provided and assemble the metagenomic data in order to analyze many complex bacterial populations.
#
# **Issues:** Our code did not run to completion. A potential explanation for this error occuring is due to the abundance of students occupying the cluster and thus taking up the memory. This then does not allow metaspades to run. Although we attempted to run this several times, it did not function do to this issues Going forward, we will continue to attempt to fix this issue by asking for a different data set. Hello
